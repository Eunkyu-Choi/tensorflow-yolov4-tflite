# %%
# %%bash
#
# python save_model.py
# Out:
# 2021-04-12 11:21:20.273837: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "save_model.py", line 4, in <module>
#     from core.yolov4 import YOLO, decode, filter_boxes
#   File "/home/localley/tensorflow-yolov4-tflite/core/yolov4.py", line 6, in <module>
#     import core.utils as utils
#   File "/home/localley/tensorflow-yolov4-tflite/core/utils.py", line 1, in <module>
#     import cv2
# ModuleNotFoundError: No module named 'cv2'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-7-d0d6794cf1d4> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\npython save_model.py\n')
#
# ~/anaconda3/envs/yolov4-gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
# ...

# %%
# %%bash
#
#
# python convert_model.py
#
# python convert_graph.py
# Out:
# tf.tile_1/Tile/input/0/9/2/0/values_0
# model/tf.tile_1/Tile/input/0/9/2/0/values_1
# model/tf.tile_1/Tile/input/0/9/2/0
# model/tf.tile_1/Tile/input/0/9/2
# model/tf.tile_1/Tile/input/0/9/3/0/values_0
# model/tf.tile_1/Tile/input/0/9/3/0/values_1
# model/tf.tile_1/Tile/input/0/9/3/0
# model/tf.tile_1/Tile/input/0/9/3
# model/tf.tile_1/Tile/input/0/9/4/0/values_0
# model/tf.tile_1/Tile/input/0/9/4/0/values_1
# model/tf.tile_1/Tile/input/0/9/4/0
# model/tf.tile_1/Tile/input/0/9/4
# model/tf.tile_1/Tile/input/0/9/5/0/values_0
# model/tf.tile_1/Tile/input/0/9/5/0/values_1
# model/tf.tile_1/Tile/input/0/9/5/0
# model/tf.tile_1/Tile/input/0/9/5
# model/tf.tile_1/Tile/input/0/9/6/0/values_0
# model/tf.tile_1/Tile/input/0/9/6/0/values_1
# model/tf.tile_1/Tile/input/0/9/6/0
# model/tf.tile_1/Tile/input/0/9/6
# model/tf.tile_1/Tile/input/0/9/7/0/values_0
# model/tf.tile_1/Tile/input/0/9/7/0/values_1
# model/tf.tile_1/Tile/input/0/9/7/0
# model/tf.tile_1/Tile/input/0/9/7
# ...

# %%
# %%bash
#
# tensorflowjs_converter --input_format=tf_frozen_model --output_node_names='Identity:0','Identity_1:0','Identity_2:0','Identity_3:0' ./checkpoints/tf2_frozen_graph.pb ./checkpoints/frozen
# Out:
# Writing weight file ./checkpoints/frozen/model.json...
# 2021-04-12 10:57:31.092520: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-12 10:57:32.901292: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:928] Optimization results for grappler item: graph_to_optimize
#   debug_stripper: debug_stripper did nothing. time = 1.075ms.
#   model_pruner: Graph size after: 3802 nodes (0), 4214 edges (0), time = 13.596ms.
#   constant_folding: Graph size after: 1968 nodes (-1834), 2380 edges (-1834), time = 194.084ms.
#   arithmetic_optimizer: Graph size after: 1968 nodes (0), 2380 edges (0), time = 34.158ms.
#   dependency_optimizer: Graph size after: 278 nodes (-1690), 294 edges (-2086), time = 29.954ms.
#   model_pruner: Graph size after: 278 nodes (0), 294 edges (0), time = 5.875ms.
#   constant_folding: Graph size after: 278 nodes (0), 294 edges (0), time = 17.446ms.
# ...

# %%
# %%bash
#
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='Identity:0','Identity_1:0','Identity_2:0','Identity_3:0'  --saved_model_tags=serve ./checkpoints/yolov4-416_tiny ./checkpoints/detect
# Out:
# 2021-04-12 11:24:46.919890: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-12 11:24:47.855115: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-12 11:24:47.861445: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-12 11:24:47.884827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-12 11:24:47.885285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# ...

# %%
# %%bash
#
# tensorflowjs_converter \
#     --input_format=tf_saved_model \
#     --output_format=tfjs_graph_model \
#     --signature_name=serving_default \
#     --saved_model_tags=serve \
#  ./checkpoints/yolov4-416_tiny ./checkpoints/detect
# Out:
# 2021-04-12 11:25:23.676035: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-12 11:25:24.608341: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-12 11:25:24.608905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-12 11:25:24.633152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-12 11:25:24.633713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# ...
